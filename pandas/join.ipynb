# %%
import numpy as np
import pandas as pd

m = np.random.randint(1,30 , size=(10,3))

df1  = pd.DataFrame(m,columns= [ "var1", "var2" , "var3"])

# %%
m
# Out:
# array([[25, 13, 25],
#        [11, 19,  1],
#        [ 9,  1,  7],
#        [16, 25, 16],
#        [ 2, 26, 11],
#        [28,  9,  4],
#        [ 8, 13, 28],
#        [13, 14, 12],
#        [14, 26, 16],
#        [ 5,  5, 23]], dtype=int32)

# %%
df1
# Out:
#    var1  var2  var3
# 0    17    15    19
# 1    29    28     4
# 2     7     6     2
# 3    20    19    26
# 4    15     9    16
# 5     2    22    21
# 6    21    29    14
# 7     9    22    27
# 8    18    29     1
# 9     7     4    13

# %%
df2 = df1 + 99

# %%
df2
# Out:
#    var1  var2  var3
# 0   116   114   118
# 1   128   127   103
# 2   106   105   101
# 3   119   118   125
# 4   114   108   115
# 5   101   121   120
# 6   120   128   113
# 7   108   121   126
# 8   117   128   100
# 9   106   103   112

# %%
pd.concat([df1,df2])
# Out:
#    var1  var2  var3
# 0    17    15    19
# 1    29    28     4
# 2     7     6     2
# 3    20    19    26
# 4    15     9    16
# 5     2    22    21
# 6    21    29    14
# 7     9    22    27
# 8    18    29     1
# 9     7     4    13
# 0   116   114   118
# 1   128   127   103
# 2   106   105   101
# 3   119   118   125
# 4   114   108   115
# 5   101   121   120
# 6   120   128   113
# 7   108   121   126
# 8   117   128   100
# 9   106   103   112

# %%
# ?pd.concat
# Out:
# Signature:
# pd.concat(
#     objs: 'Iterable[Series | DataFrame] | Mapping[HashableT, Series | DataFrame]',
#     *,
#     axis: 'Axis' = 0,
#     join: 'str' = 'outer',
#     ignore_index: 'bool' = False,
#     keys: 'Iterable[Hashable] | None' = None,
#     levels=None,
#     names: 'list[HashableT] | None' = None,
#     verify_integrity: 'bool' = False,
#     sort: 'bool' = False,
#     copy: 'bool | None' = None,
# ) -> 'DataFrame | Series'
# Docstring:
# Concatenate pandas objects along a particular axis.
#
# Allows optional set logic along the other axes.
#
# Can also add a layer of hierarchical indexing on the concatenation axis,
# which may be useful if the labels are the same (or overlapping) on
# the passed axis number.
#
# Parameters
# ----------
# objs : a sequence or mapping of Series or DataFrame objects
#     If a mapping is passed, the sorted keys will be used as the `keys`
#     argument, unless it is passed, in which case the values will be
# ...

# %%
pd.concat([df1,df2] , ignore_index = False,)
# Out:
#    var1  var2  var3
# 0    17    15    19
# 1    29    28     4
# 2     7     6     2
# 3    20    19    26
# 4    15     9    16
# 5     2    22    21
# 6    21    29    14
# 7     9    22    27
# 8    18    29     1
# 9     7     4    13
# 0   116   114   118
# 1   128   127   103
# 2   106   105   101
# 3   119   118   125
# 4   114   108   115
# 5   101   121   120
# 6   120   128   113
# 7   108   121   126
# 8   117   128   100
# 9   106   103   112

# %%
pd.concat([df1,df2] , ignore_index = True,)
# Out:
#     var1  var2  var3
# 0     17    15    19
# 1     29    28     4
# 2      7     6     2
# 3     20    19    26
# 4     15     9    16
# 5      2    22    21
# 6     21    29    14
# 7      9    22    27
# 8     18    29     1
# 9      7     4    13
# 10   116   114   118
# 11   128   127   103
# 12   106   105   101
# 13   119   118   125
# 14   114   108   115
# 15   101   121   120
# 16   120   128   113
# 17   108   121   126
# 18   117   128   100
# 19   106   103   112

# %%
dfOne = pd.DataFrame({"workers": ["Andrew", "Daniel" , "David", "john"],
                      "group": ["Ml enginer", "Ai enginer", "software enginer","java enginer"]})
dfOne
# Out:
#   workers             group
# 0  Andrew        Ml enginer
# 1  Daniel        Ai enginer
# 2   David  software enginer
# 3    john      java enginer

# %%
dfTwo = pd.DataFrame({"workers": ["Andrew", "Daniel" , "David", "john"],
                      "first entry": [2020, 2021, 2022,2023]})
dfTwo
# Out:
#   workers  first entry
# 0  Andrew         2020
# 1  Daniel         2021
# 2   David         2022
# 3    john         2023

# %%
 dfAll = pd.merge(dfOne,dfTwo)

# %%
dfThree = pd.DataFrame({"workers": ["Andrew", "Daniel" , "David", "john"],
                      "level": ["Senior", "Middle", "Junior","Intern"]})

dfThree
# Out:
#   workers   level
# 0  Andrew  Senior
# 1  Daniel  Middle
# 2   David  Junior
# 3    john  Intern

# %%
pd.merge(dfAll , dfThree)
# Out:
#   workers             group  first entry   level
# 0  Andrew        Ml enginer         2020  Senior
# 1  Daniel        Ai enginer         2021  Middle
# 2   David  software enginer         2022  Junior
# 3    john      java enginer         2023  Intern
